# %% [markdown]
# # Project Information
#
# **Project Title:**
# Analysing International Trade Data Using Machine Learning Techniques
#
# **Student Name(s) & Enrolment Number(s):**
# Rajiv Ranjan (055038), Arnav Mehra (055030)
#
# **Group Number:** 12
#
# ---
#
# ## Description of Data
#
# **Data Source:** [Kaggle - Imports Exports Dataset](https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000)
# **Data Size:** 1 MB
# **Data Type:** Cross-sectional
# **Data Dimensions:**
# - Number of Variables: 16
# - Number of Observations: 15001
#
# ### Data Variable Types
# - **Numeric Variables:**
#   - Quantity (Integer)
#   - Value (Decimal)
#   - Customs_Code (Integer)
#   - Weight (Decimal)
#   - Invoice Number (Integer)
#
# - **Non-Numeric Variables:**
#   - Transaction_ID
#   - Country
#   - Product
#   - Import-Export
#   - Date
#   - Category
#   - Port
#   - Shipping_Method
#   - Supplier
#   - Customer
#   - Payment Terms
#
# ### Data Variable Categories
# - **Category-I (Index | Categorical | Non-categorical):**
#   - **Categorical:** 'Country', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms'
#   - **Non-categorical:** 'Quantity', 'Value', 'Weight'
#   - **Index:**     ' Transaction_ID'
#
# - **Category-II (Input Variables | Outcome Variables):**
#   - Input Variables (Features): Provide information for analysis and clustering.
#   - Outcome Variables: Not explicitly defined as this is an unsupervised learning project.
#
# **About the Dataset:**
# This dataset contains detailed international trade transactions, capturing various attributes of imports and exports. It supports business analytics, economic research, and financial modeling.
#
# ---
#
# ## Objectives, Findings, and Managerial Insights
#
# ### **1. Data Completeness Analysis**
#
# #### **Objective:**
# To evaluate the completeness of the dataset by analyzing missing data statistics for all variables.
#
# #### **Findings:**
# - All variables in the dataset have 0 missing values.
# - The dataset is complete, with 0% missing data for all 15 variables.
#
# #### **Managerial Insights:**
# - **High Data Quality:** The absence of missing data ensures that the dataset can be analyzed without the need for imputation or deletion of records, leading to accurate and reliable results.
# - **Robust Model Training:** A complete dataset allows for seamless implementation of machine learning models, avoiding biases or inaccuracies caused by missing data.
# - **Efficient Data Processing:** The high data quality reduces preprocessing efforts, enabling managers to focus on extracting actionable insights and driving business decisions.
#
# ---
#
# ### **2. Distribution Analysis of Categorical Variables**
#
# #### **Objective:**
# To analyze the distribution of key categorical variables (Import_Export, Category, Shipping_Method, and Payment_Terms) to identify trade patterns and trends.
#
# #### **Findings:**
# - **Import vs. Export:** Imports account for 51% of transactions, slightly higher than exports (49%).
# - **Category Distribution:**
#   - Clothing: 21%
#   - Machinery: 20%
#   - Electronics: 20%
#   - Furniture: 20%
#   - Toys: 19%
# - **Shipping Methods:**
#   - Air: 34%
#   - Land: 34%
#   - Sea: 32%
# - **Payment Terms:**
#   - Cash on Delivery: 26%
#   - Prepaid: 25%
#   - Net 60: 25%
#   - Net 30: 25%
#
# #### **Managerial Insights:**
# - **Balanced Trade Flow:** The near-equal split between imports and exports highlights a balanced trade ecosystem. Strategies can focus equally on optimizing both trade flows.
# - **Product Diversity:** The even distribution across product categories suggests potential for targeted strategies for each category, ensuring equitable resource allocation.
# - **Shipping Method Efficiency:** The close usage percentages of Air, Land, and Sea indicate diverse logistics needs. Managers can evaluate cost, speed, and reliability to optimize shipping methods for different transaction types.
# - **Payment Flexibility:** The equal distribution of payment terms reflects diverse customer preferences. Businesses can maintain this flexibility while exploring incentives (e.g., discounts for prepaid orders) to improve cash flow.
#
# ---
#
# ### **3. Correlation Analysis of Categorical Variables**
#
# #### **Objective:**
# To analyze the correlations between key categorical variables (Import_Export, Category, Shipping_Method, and Payment_Terms) to determine their interdependencies and potential relationships.
#
# #### **Findings:**
# - **Import_Export:** Weak negative correlation with other variables (Spearman: -0.0177, Kendall: -0.0161), indicating independence from other categorical factors.
# - **Category:** Weak positive correlations (Spearman: 0.0063, Kendall: 0.0052) with other variables, suggesting no strong relationship with shipping or payment terms.
# - **Shipping_Method and Payment_Terms:** Minimal positive correlations (Spearman: 0.0104, Kendall: 0.0090), indicating very weak or no meaningful association.
#
# #### **Managerial Insights:**
# - **Independence of Variables:** The weak correlations indicate that the variables operate independently. Managers can design separate strategies for logistics, payment terms, and trade types without interdependencies affecting outcomes.
# - **Flexibility in Planning:** The independence of Shipping_Method and Payment_Terms allows businesses to offer flexible options to customers without significant trade-offs in trade flows or categories.
# - **Cluster-Based Decisions:** Since the variables are not strongly related, segmentation (e.g., clustering) can help uncover patterns and optimize strategies for distinct groups of transactions.
#
# ---
#
# ### **4. Statistical Distribution of Numeric Variables**
#
# #### **Objective:**
# To analyze the statistical distribution of numeric variables (Quantity, Value, and Weight) and assess central tendencies, spread, and key percentiles.
#
# #### **Findings:**
# - **Quantity:**
#   - Range: 6 to 10,000, indicating significant variability.
#   - Central Tendency: Mean (4,977.82) ≈ Median (5,018.0), suggesting symmetry in distribution.
#   - Mode: 5,855, representing the most common quantity.
#   - Interquartile Range (IQR): 7,502 - 2,442 = 5,060, showing moderate spread.
# - **Value:**
#   - Range: 106.83 to 9,998.07, highlighting diversity in transaction values.
#   - Central Tendency: Mean (5,107.26) ≈ Median (5,119.42), reflecting symmetry.
#   - Mode: 154.7, representing frequent low-value transactions.
#   - IQR: 7,562.27 - 2,679.92 = 4,882.35, indicating variability in trade values.
# - **Weight:**
#   - Range: 1.52 to 4,998.01, showcasing a narrower spread compared to Quantity and Value.
#   - Central Tendency: Mean (2,512.00) ≈ Median (2,499.06), indicating symmetry.
#   - Mode: 23.38, highlighting frequent small-weight shipments.
#   - IQR: 3,758.95 - 1,266.69 = 2,492.26, showing moderate variability.
#
# #### **Managerial Insights:**
# - **Balanced Distribution:** The close alignment of mean and median for all variables suggests stable trade patterns with no extreme skewness, allowing managers to rely on central tendencies for planning.
# - **Frequent Order Characteristics:** Common values for Quantity (5,855), Value (154.7), and Weight (23.38) indicate typical transaction characteristics. Managers can optimize inventory and logistics to cater to these frequent scenarios.
# - **Diverse Trade Patterns:** The wide ranges and high IQRs in Quantity and Value highlight the need to segment trade data into clusters to identify patterns like bulk orders, high-value transactions, or low-weight shipments.
#
# ---
#
# ### **5. Variability and Symmetry Analysis**
#
# #### **Objective:**
# To evaluate the variability, distribution symmetry, and tail behavior of numeric variables (Quantity, Value, and Weight) using statistical measures.
#
# #### **Findings:**
# - **Quantity:**
#   - Range: 9,994, showing high variability in transaction sizes.
#   - Standard Deviation: 2,887.64, indicating moderate dispersion.
#   - Skewness: -0.0004 (close to 0), suggesting a symmetric distribution.
#   - Kurtosis: -1.1961, indicating a flatter distribution with fewer extreme values.
# - **Value:**
#   - Range: 9,891.24, reflecting a wide spread in transaction values.
#   - Standard Deviation: 2,839.41, showing moderate variability.
#   - Skewness: -0.0150, close to 0, indicating near symmetry.
#   - Kurtosis: -1.1854, suggesting fewer outliers and a flat distribution.
# - **Weight:**
#   - Range: 4,996.49, demonstrating variability in shipment sizes.
#   - Standard Deviation: 1,452.01, indicating moderate spread.
#   - Skewness: 0.0194, nearly 0, showing symmetry.
#   - Kurtosis: -1.2135, representing a flat distribution with lighter tails.
#
# #### **Managerial Insights:**
# - **Symmetric Trade Data:** The near-zero skewness across all variables suggests a balanced dataset, enabling managers to make reliable decisions based on central tendencies without significant influence from extreme values.
# - **Low Risk of Outliers:** The negative kurtosis values confirm a flat distribution, indicating fewer extreme values. This ensures that trade data is consistent and predictable, reducing the need for outlier mitigation strategies.
# - **Segmented Strategies:** The wide ranges and moderate variability highlight opportunities for segmenting trade transactions by size, value, and weight to tailor strategies for bulk orders, lightweight shipments, and high-value goods.
#
# ---
#
# ### **6. Correlation Analysis of Numeric Variables**
#
# #### **Objective:**
# To analyze the relationships between the numeric variables (Quantity, Value, and Weight) using Pearson and Spearman correlation coefficients.
#
# #### **Findings:**
# - **Quantity:**
#   - Pearson Correlation: -0.0004, suggesting no linear relationship with the other variables.
#   - Spearman Correlation: -0.0002, indicating no monotonic relationship.
# - **Value and Weight:**
#   - Both have Pearson and Spearman correlations of 0.0319 and 0.0320, respectively, which are very weak positive correlations, showing almost no association between Value and Weight.
#
# #### **Managerial Insights:**
# - **Independent Variables:** The weak correlations indicate that Quantity, Value, and Weight are largely independent of one another. This allows managers to optimize strategies for each variable separately, without worrying about their mutual influence.
# - **Flexibility in Decision-Making:** The lack of significant correlation suggests that trade strategies (e.g., pricing, shipping, or inventory decisions) can be developed independently for Quantity, Value, and Weight.
# - **Cluster-Based Segmentation:** Given the independence of variables, clustering will be more effective for discovering unique trade patterns rather than relying on direct relationships between these numeric factors.
#
# ---
#
# ### **7. Coefficient of Variation (CV) and Confidence Intervals**
#
# #### **Objective:**
# To evaluate the variability and reliability of numeric variables (Quantity, Value, and Weight) using the coefficient of variation (CV) and confidence intervals.
#
# #### **Findings:**
# - **Quantity:**
#   - Coefficient of Variation (CV): 58.01%, indicating moderate variability relative to the mean.
#   - 95% Confidence Interval: The true mean lies between 4,897.77 and 5,057.87 with 95% confidence.
# - **Value:**
#   - CV: 55.60%, showing moderate variability relative to the mean.
#   - 95% Confidence Interval: The true mean lies between 5,028.55 and 5,185.97 with 95% confidence.
# - **Weight:**
#   - CV: 57.80%, reflecting similar variability as Quantity and Value.
#   - 95% Confidence Interval: The true mean lies between 2,471.75 and 2,552.25 with 95% confidence.
#
# #### **Managerial Insights:**
# - **Moderate Variability:** The CV values (~55–58%) indicate moderate variability across all three variables. Managers should account for these fluctuations when planning inventory, logistics, and pricing strategies.
# - **Reliable Mean Estimates:** The narrow confidence intervals for all variables suggest that their means are statistically reliable. These can serve as benchmarks for forecasting and decision-making.
# - **Focus Areas:** The moderate variability and reliable means highlight opportunities for cluster-based segmentation, allowing managers to identify trade patterns and refine operational strategies.
#
# ---
#
# The remaining sections, including the results of clustering and normalization, will follow this format. Let me know if you want additional sections included or specific formatting changes!
#
# ---
#
# ### **8. Numerical Encoding of Categorical Variables**
#
# #### **Objective:**
# To prepare categorical variables (Import_Export, Category, Shipping_Method, and Payment_Terms) for machine learning analysis by applying numerical encoding.
#
# #### **Findings:**
# - **Encoding Completed:**
#   - Import_Export_code: Encodes Import/Export.
#   - Category_code: Encodes product categories.
#   - Shipping_Method_code: Encodes shipping methods (e.g., Air, Land, Sea).
#   - Payment_Terms_code: Encodes payment terms (e.g., Prepaid, Net 30).
# - **Standardized Representation:** The encoded dataset is now ready for clustering or predictive modeling, ensuring all variables are represented numerically.
#
# #### **Managerial Insights:**
# - **Enhanced Model Compatibility:** Numerical encoding allows categorical data to be seamlessly integrated into machine learning algorithms, improving model accuracy and performance.
# - **Interpretability in Clusters:** The encoded variables provide a standardized framework for interpreting clusters. For example, analyzing patterns between Category_code and Shipping_Method_code can reveal logistical trends.
# - **Efficient Processing:** By encoding the categorical data, computational efficiency is improved, enabling faster and more reliable results during model training and evaluation.
#
# ---
#
# ### **9. Normalization of Numeric Variables**
#
# #### **Objective:**
# To normalize the numeric variables (Quantity, Value, and Weight) using the Min-Max scaling technique for improved model performance and feature comparability.
#
# #### **Findings:**
# - **Min-Max Scaling Applied:**
#   - All numeric variables are rescaled to a range between 0 and 1, ensuring comparability regardless of their original scales.
#   - Example scaled values:
#     - Quantity: 0.69, 0.50, 0.26, etc.
#     - Value: 0.45, 0.16, 0.21, etc.
#     - Weight: 0.06, 0.65, 0.43, etc.
# - **Preserved Relationships:** The scaling preserves the relative distribution of data while bringing all variables into a common scale.
#
# #### **Managerial Insights:**
# - **Improved Model Performance:** By normalizing numeric variables, models like K-Means or Hierarchical Clustering will perform better, as all features are equally weighted.
# - **Enhanced Interpretability:** Scaled data ensures that patterns and clusters reflect genuine trade dynamics, not distortions caused by differing variable scales.
# - **Better Comparability:** Managers can now directly compare variables (e.g., how Quantity relates to Value) without bias from scale differences, aiding in decision-making.
#
# ---
#
# ### **10. K-Means Clustering**
#
# #### **Objective:**
# To segment the dataset into distinct groups using the K-Means Clustering algorithm and analyze the cluster assignments for actionable trade insights.
#
# #### **Findings:**
# - **Clusters Identified:**
#   - The K-Means algorithm assigned countries and their associated products into 4 clusters.
# - **Cluster Characteristics:**
#   - Cluster 0: Low-quantity, low-value transactions, likely smaller-scale or niche trade activities.
#   - Cluster 1: Moderate quantities and values, potentially consistent trade patterns across mid-sized markets.
#   - Cluster 2: High-value but low-quantity transactions, indicating premium goods or high-value exports.
#   - Cluster 3: High-quantity and high-value transactions, likely bulk trade or large-scale operations.
# - **Trade Trends:** Variability in shipping methods (Air, Land, Sea) and payment terms (Prepaid, Net 30, etc.) is distributed across clusters, showing logistical and financial flexibility in trade operations.
#
# #### **Managerial Insights:**
# - **Tailored Strategies:**
#   - Cluster 0: Focus on improving cost efficiency and identifying growth opportunities for smaller trade transactions.
#   - Cluster 1: Maintain consistency in operations and strengthen mid-sized trade relationships.
#   - Cluster 2: Invest in premium logistics and customer service to maximize profits from high-value, low-quantity transactions.
#   - Cluster 3: Optimize supply chain management for bulk trade, ensuring timely delivery and cost control.
# - **Logistics Optimization:** Use the cluster insights to allocate appropriate shipping methods based on transaction size and value, ensuring cost-efficiency and customer satisfaction.
# - **Market Insights:** The segmentation highlights diverse market dynamics, enabling targeted marketing campaigns and tailored product offerings for each cluster.
#
# ---
#
# ### **11. Agglomerative Clustering**
#
# #### **Objective:**
# To analyze and interpret trade patterns using Agglomerative Clustering across different cluster configurations (2 to 5 clusters) and derive actionable insights for optimizing trade strategies.
#
# #### **Findings:**
# - **Cluster Quality:**
#   - Across all configurations, the Silhouette Scores were relatively low (ranging from 0.2190 to 0.2776), indicating weak intra-cluster cohesion and inter-cluster separation.
#   - Davies-Bouldin Scores ranged from 1.1124 (4 clusters) to 1.4332 (2 clusters), reflecting moderate-to-high overlap among clusters.
# - **Optimal Configuration:**
#   - The 4-cluster Agglomerative model offered the best performance among Agglomerative configurations, with a Silhouette Score of 0.2472 and a Davies-Bouldin Score of 1.1124.
# - **Cluster Characteristics:**
#   - Cluster 1: Represents smaller transactions with low quantities and values.
#   - Cluster 2: Includes mid-sized transactions, with moderate trade values and weights.
#   - Cluster 3: Characterizes premium, high-value, low-quantity trades, often requiring specialized logistics.
#   - Cluster 4: Comprises bulk trade with high quantities and high values, indicating large-scale operations.
#
# #### **Managerial Insights:**
# - **Segment-Specific Strategies:**
#   - Cluster 1: Optimize logistics for small-scale trade to reduce costs and improve efficiency.
#   - Cluster 2: Maintain consistency in mid-sized operations, leveraging steady trade flows.
#   - Cluster 3: Focus on high-value services, such as premium logistics and risk management, to maximize profitability.
#   - Cluster 4: Streamline bulk operations by investing in scalable supply chains and optimizing inventory management.
# - **Refinement Opportunities:** While Agglomerative Clustering provides useful segmentation, its performance is inferior to K-Means. Consider refining clustering using alternative linkage methods (e.g., average or complete linkage).
# - **Data-Driven Decision-Making:** The segmentation offers a foundation for tailored trade strategies, but the low Silhouette Scores suggest the need for further exploration of feature engineering or algorithm selection to achieve more distinct clusters.
#
# ---
#
# ### **Conclusion**
#
# K-Means Clustering emerged as the superior method for trade segmentation with better-defined clusters and actionable insights. The dataset's completeness, balanced distribution, and normalized scaling enable efficient machine learning workflows, paving the way for robust trade analytics. Managers can leverage these insights to optimize logistics, streamline operations, and create targeted strategies for different trade clusters.

# %% [markdown]
# # Pre Processing Of Data

# %% [markdown]
# # importing the necessary librarires

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import scipy.stats as sps # For Probability & Inferential Statistics
import time
import psutil
import os
import pandas as pd
import numpy as np
from scipy.stats import spearmanr, kendalltau
from scipy.stats import skew, kurtosis
from scipy.stats import pearsonr, spearmanr
from scipy.stats import sem, t

# %% [markdown]
# # Loading and categorizing the data

# %%
# Display All Columns of Dataset
pd.set_option('display.max_columns', None)

# %%
#2. Load the Data.
import pandas as pd
import requests
from io import StringIO

# Replace with your actual file ID
file_id ='1pkzb6aFBHav97rislqkJYDN2fnlKlf43'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
rr38_df = pd.read_csv(StringIO(response.text))

# Display the first few rows of the DataFrame
rr38_df.head(2)
# Out:
#                          Transaction_ID   Country    Product Import_Export  \
# 0  e3e70682-c209-4cac-a29f-6fbed82c07cd  Colombia   describe        Export
# 1  f728b4fa-4248-4e3a-8a5d-2f346baa9455     Chile  president        Export
#
#    Quantity    Value        Date   Category        Port  Customs_Code  \
# 0      1979  9506.57  07-12-2023  Machinery  Robertbury        620537
# 1      5763  7100.91  04-04-2023   Clothing    Shahport        927600
#
#     Weight Shipping_Method                         Supplier       Customer  \
# 0  4248.65             Air  Garrison, Hubbard and Hendricks      Seth Hall
# 1  4340.81             Air                        Webb-Mack  Kimberly Ryan
#
#    Invoice_Number     Payment_Terms
# 0        21000294  Cash on Delivery
# 1        88738432           Prepaid

# %%
#7. Display the Dimensions of Sample Data.
rr38_sdf = rr38_df.sample(n=5001, random_state=55038)
print(rr38_sdf.shape)
# Out:
# (5001, 16)

# %%
#8. Display Sample Data Information.
print("\nInformation about the Sample DataFrame:")
rr38_sdf.info()
# Out:
# Information about the Sample DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 4972 to 2188
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# ...

# %%
rr38_sdf.columns
# Out:
# Index(['Transaction_ID', 'Country', 'Product', 'Import_Export', 'Quantity',
#        'Value', 'Date', 'Category', 'Port', 'Customs_Code', 'Weight',
#        'Shipping_Method', 'Supplier', 'Customer', 'Invoice_Number',
#        'Payment_Terms'],
#       dtype='object')

# %%
# Data Bifurcation
rr38_sdf_cat = rr38_sdf[['Country', 'Import_Export', 'Category', 'Port', 'Shipping_Method', 'Supplier', 'Customer', 'Payment_Terms']] # Categorical Data [Nominal | Ordinal]
rr38_sdf_nononcat=rr38_sdf[['Quantity', 'Value', 'Weight']]# Non-Categorical Data

# %%
#to find out te relevant categorical variables
for column in rr38_sdf_cat.columns:
    grouped_data = rr38_sdf_cat.groupby(column).size().reset_index(name='counts')
    print(f"Grouped by {column}:\n{grouped_data}\n")
# Out:
# Grouped by Country:
#                Country  counts
# 0          Afghanistan      19
# 1              Albania      29
# 2              Algeria      31
# 3       American Samoa      26
# 4              Andorra      12
# ..                 ...     ...
# 238  Wallis and Futuna      23
# 239     Western Sahara      21
# 240              Yemen      17
# 241             Zambia      17
# 242           Zimbabwe      18
#
# [243 rows x 2 columns]
#
# Grouped by Import_Export:
#   Import_Export  counts
# 0        Export    2456
# 1        Import    2545
#
# Grouped by Category:
#       Category  counts
# 0     Clothing    1030
# 1  Electronics     995
# 2    Furniture     985
# 3    Machinery    1023
# 4         Toys     968
#
# Grouped by Port:
#                 Port  counts
# 0       Aaronborough       1
# 1         Aaronmouth       3
# 2          Aaronport       1
# 3          Aaronstad       1
# 4          Aaronview       1
# ...              ...     ...
# 4244     Zacharyport       1
# ...

# %%
#Relevant categorical variable
# Data Bifurcation
rr38_sdf_cat = rr38_sdf[[ 'Import_Export', 'Category', 'Shipping_Method',  'Payment_Terms']] # Categorical Data [Nominal | Ordinal]
rr38_sdf_noncat=rr38_sdf[['Quantity', 'Value', 'Weight']]# Non-Categorical Data

# %%
rr38_sdf_cat.head()
# Out:
#       Import_Export     Category Shipping_Method     Payment_Terms
# 4972         Import         Toys             Sea  Cash on Delivery
# 10055        Import    Machinery             Sea           Prepaid
# 2920         Import  Electronics             Sea            Net 60
# 11695        Import  Electronics             Sea  Cash on Delivery
# 9363         Import         Toys             Air            Net 60

# %%
rr38_sdf_noncat.head()
# Out:
#        Quantity    Value   Weight
# 4972       6902  4536.94   304.33
# 10055      5019  1667.66  3254.05
# 2920       2623  2217.23  2161.28
# 11695      7669  6934.78  2504.32
# 9363       5704  9951.30   733.41

# %% [markdown]
# # Missing Data Report

# %%
rr38_record_missing_data = rr38_sdf.isna().sum(axis=1).sort_values(ascending=False).head(5);
rr38_record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# 4972     0
# 4605     0
# 2635     0
# 12168    0
# 3762     0
# dtype: int64

# %%
# Calculate missing data statistics for each variable
missing_data = rr38_sdf.isnull().sum()
total_records = len(rr38_sdf)

# Calculate percentage of missing data
percentage_missing = (missing_data / total_records) * 100

# Create a DataFrame to display the results
missing_data_summary = pd.DataFrame({
    'Variable': missing_data.index,
    'Missing Count': missing_data.values,
    'Percentage Missing': percentage_missing.values
})

# Display the summary
print("Missing Data Statistics:\n", missing_data_summary)
# Out:
# Missing Data Statistics:
#             Variable  Missing Count  Percentage Missing
# 0    Transaction_ID              0                 0.0
# 1           Country              0                 0.0
# 2           Product              0                 0.0
# 3     Import_Export              0                 0.0
# 4          Quantity              0                 0.0
# 5             Value              0                 0.0
# 6              Date              0                 0.0
# 7          Category              0                 0.0
# 8              Port              0                 0.0
# 9      Customs_Code              0                 0.0
# 10           Weight              0                 0.0
# 11  Shipping_Method              0                 0.0
# 12         Supplier              0                 0.0
# 13         Customer              0                 0.0
# 14   Invoice_Number              0                 0.0
# 15    Payment_Terms              0                 0.0

# %%
# Calculate missing data statistics for each record
record_missing_data = rr38_sdf.isnull().sum(axis=1)
total_columns = rr38_sdf.shape[1]

# Calculate percentage of missing data for each record
percentage_missing_record = (record_missing_data / total_columns) * 100

# Create a DataFrame to display the results
missing_data_record_summary = pd.DataFrame({
    'Record Index': rr38_sdf.index,
    'Missing Count': record_missing_data.values,
    'Percentage Missing': percentage_missing_record.values
})

# Display the summary
print("Record-wise Missing Data Statistics:\n", missing_data_record_summary)
# Out:
# Record-wise Missing Data Statistics:
#        Record Index  Missing Count  Percentage Missing
# 0             4972              0                 0.0
# 1            10055              0                 0.0
# 2             2920              0                 0.0
# 3            11695              0                 0.0
# 4             9363              0                 0.0
# ...            ...            ...                 ...
# 4996          4318              0                 0.0
# 4997         12037              0                 0.0
# 4998          9891              0                 0.0
# 4999         13700              0                 0.0
# 5000          2188              0                 0.0
#
# [5001 rows x 3 columns]

# %%
rr38_cat_mdi = rr38_sdf_cat

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## Categorical Data Descreptive Statistics

# %%
#For Categorical Data
for i in rr38_sdf_cat:
  rr38_count_stats = pd.concat([rr38_sdf_cat[i].value_counts(), rr38_sdf_cat[i].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
  print(i," : \n ",rr38_count_stats,"\n")
# Out:
# Import_Export  :
#     Import_Export  count  percentage
# 0        Import   2545        51.0
# 1        Export   2456        49.0
#
# Category  :
#         Category  count  percentage
# 0     Clothing   1030        21.0
# 1    Machinery   1023        20.0
# 2  Electronics    995        20.0
# 3    Furniture    985        20.0
# 4         Toys    968        19.0
#
# Shipping_Method  :
#     Shipping_Method  count  percentage
# 0             Air   1707        34.0
# 1            Land   1676        34.0
# 2             Sea   1618        32.0
#
# Payment_Terms  :
#         Payment_Terms  count  percentage
# 0  Cash on Delivery   1304        26.0
# 1           Prepaid   1243        25.0
# 2            Net 60   1227        25.0
# 3            Net 30   1227        25.0

# %%
# Spearman and Kendall's Ranl correlation


# Create an empty DataFrame to store the results
correlation_results = pd.DataFrame(index=rr38_sdf_cat.columns,
                                    columns=['Spearman', 'Kendall'])

# Loop through each pair of columns in the DataFrame
for col1 in rr38_sdf_cat.columns:
    for col2 in rr38_sdf_cat.columns:
        if col1 != col2:  # Avoid calculating correlation with itself
            # Calculate Spearman's rank correlation
            spearman_corr, _ = spearmanr(rr38_sdf_cat[col1],
                                         rr38_sdf_cat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Calculate Kendall's rank correlation
            kendall_corr, _ = kendalltau(rr38_sdf_cat[col1],
                                         rr38_sdf_cat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Store the results in the DataFrame
            correlation_results.loc[col1, 'Spearman'] = spearman_corr
            correlation_results.loc[col1, 'Kendall'] = kendall_corr

# Display the results
print("Correlation Results:\n", correlation_results)
# Out:
# Correlation Results:
#                   Spearman   Kendall
# Import_Export   -0.017659 -0.016121
# Category         0.006312   0.00522
# Shipping_Method  0.010434  0.008982
# Payment_Terms    0.010434  0.008982

# %% [markdown]
# ## Non Categorical Descreptive Statistics

# %%
#basic descreptive statistics non categorical data

# Create an empty dictionary to store the results
central_tendency_results = {}

# Loop through each column in the DataFrame
for column in rr38_sdf_noncat.columns:
    # Calculate measures of central tendency
    minimum = rr38_sdf_noncat[column].min()
    maximum = rr38_sdf_noncat[column].max()
    mean = rr38_sdf_noncat[column].mean()
    median = rr38_sdf_noncat[column].median()
    mode = rr38_sdf_noncat[column].mode()[0]  # Get the first mode if multiple exist
    percentile_25 = np.percentile(rr38_sdf_noncat[column], 25)  # 25th percentile
    percentile_75 = np.percentile(rr38_sdf_noncat[column], 75)  # 75th percentile

    # Store the results in the dictionary
    central_tendency_results[column] = {
        'Minimum': minimum,
        'Maximum': maximum,
        'Mean': mean,
        'Median': median,
        'Mode': mode,
        '25th Percentile': percentile_25,
        '75th Percentile': percentile_75
    }

# Display the results
for column, stats in central_tendency_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Minimum: 6
#   Maximum: 10000
#   Mean: 4977.817636472705
#   Median: 5018.0
#   Mode: 5855
#   25th Percentile: 2442.0
#   75th Percentile: 7502.0
# --------------------
# Variable: Value
#   Minimum: 106.83
#   Maximum: 9998.07
#   Mean: 5107.2603299340135
#   Median: 5119.42
#   Mode: 154.7
#   25th Percentile: 2679.92
#   75th Percentile: 7562.27
# --------------------
# Variable: Weight
#   Minimum: 1.52
#   Maximum: 4998.01
#   Mean: 2511.9994041191762
#   Median: 2499.06
#   Mode: 23.38
#   25th Percentile: 1266.69
#   75th Percentile: 3758.95
# --------------------

# %%
# Create an empty dictionary to store the results
dispersion_results = {}

# Loop through each column in the DataFrame
for column in rr38_sdf_noncat.columns:
    # Calculate measures of dispersion
    data = rr38_sdf_noncat[column].dropna()  # Remove missing values for calculations
    range_val = data.max() - data.min()
    std_dev = data.std()
    skewness = skew(data)
    kurtosis_val = kurtosis(data)

    # Store the results in the dictionary
    dispersion_results[column] = {
        'Range': range_val,
        'Standard Deviation': std_dev,
        'Skewness': skewness,
        'Kurtosis': kurtosis_val
    }

# Display the results
for column, stats in dispersion_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Range: 9994
#   Standard Deviation: 2887.638760222075
#   Skewness: -0.0004038993278068211
#   Kurtosis: -1.1960835484958012
# --------------------
# Variable: Value
#   Range: 9891.24
#   Standard Deviation: 2839.4086402652265
#   Skewness: -0.014948153303441316
#   Kurtosis: -1.1853759448961294
# --------------------
# Variable: Weight
#   Range: 4996.49
#   Standard Deviation: 1452.0056078471594
#   Skewness: 0.019436563949245065
#   Kurtosis: -1.213477868983229
# --------------------

# %%
# Pearson and Spearman correlation

# Create an empty DataFrame to store the results
correlation_results = pd.DataFrame(index=rr38_sdf_noncat.columns,
                                    columns=['Pearson', 'Spearman'])

# Loop through each pair of columns in the DataFrame
for col1 in rr38_sdf_noncat.columns:
    for col2 in rr38_sdf_noncat.columns:
        if col1 != col2:  # Avoid calculating correlation with itself
            # Calculate Pearson correlation
            pearson_corr, _ = pearsonr(rr38_sdf_noncat[col1],
                                       rr38_sdf_noncat[col2])

            # Calculate Spearman correlation
            spearman_corr, _ = spearmanr(rr38_sdf_noncat[col1],
                                         rr38_sdf_noncat[col2],
                                         nan_policy='omit')  # Handle missing values

            # Store the results in the DataFrame
            correlation_results.loc[col1, 'Pearson'] = pearson_corr
            correlation_results.loc[col1, 'Spearman'] = spearman_corr

# Display the results
print("Correlation Results:\n", correlation_results)
# Out:
# Correlation Results:
#             Pearson  Spearman
# Quantity -0.000363 -0.000187
# Value     0.031951  0.032029
# Weight    0.031951  0.032029

# %%
# coefficient of variation and confidence interval

# Create an empty dictionary to store the results
composite_results = {}

# Loop through each column in the DataFrame
for column in rr38_sdf_noncat.columns:
    # Calculate measures
    data = rr38_sdf_noncat[column].dropna()  # Remove missing values for calculations

    # Coefficient of Variation
    cv = (data.std() / data.mean()) * 100

    # Confidence Interval (95% confidence level)
    confidence_level = 0.95
    degrees_of_freedom = len(data) - 1

    # Calculate standard error of the mean
    sem_val = sem(data)

    # Calculate confidence interval
    confidence_interval = t.interval(confidence_level,
                                     degrees_of_freedom,
                                     loc=data.mean(),
                                     scale=sem_val)

    # Store the results in the dictionary
    composite_results[column] = {
        'Coefficient of Variation': cv,
        'Confidence Interval (95%)': confidence_interval
    }

# Display the results
for column, stats in composite_results.items():
    print(f"Variable: {column}")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)
# Out:
# Variable: Quantity
#   Coefficient of Variation: 58.01013558761593
#   Confidence Interval (95%): (4897.766469087357, 5057.868803858053)
# --------------------
# Variable: Value
#   Coefficient of Variation: 55.59553374679673
#   Confidence Interval (95%): (5028.546198696977, 5185.97446117105)
# --------------------
# Variable: Weight
#   Coefficient of Variation: 57.80278472463651
#   Confidence Interval (95%): (2471.746881691718, 2552.2519265466344)
# --------------------

# %% [markdown]
# # Data Vizualization

# %% [markdown]
# ## Categorical  Data Vizualization

# %%
#bar chart

grouped_data = rr38_sdf.groupby('Import_Export')['Value'].sum().reset_index()

# Create the bar graph
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.bar(grouped_data['Import_Export'], grouped_data['Value'])

# Add labels and title
plt.xlabel('Import/Export Category')
plt.ylabel('Total Value')
plt.title('Total Value by Import/Export Category')

# Rotate x-axis labels if needed
plt.xticks(rotation=45, ha='right')  # Adjust rotation and alignment as needed

# Show the graph
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming rr38_sdf_cat is your DataFrame

# Get the value counts of 'Payment_Terms'
payment_counts = rr38_sdf_cat['Payment_Terms'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.pie(payment_counts, labels=payment_counts.index, autopct='%1.1f%%', startangle=90)

# Add title
plt.title('Distribution of Payment Methods')

# Ensure the circle's proportion is correct
plt.axis('equal')

# Show the chart
plt.show()

# %%
# Assuming rr38_sdf is your DataFrame and contains 'Date', 'Import_Export', and 'Value' columns

# Convert 'Date' column to datetime if it's not already
#rr38_sdf['Date'] = pd.to_datetime(rr38_sdf['Date']) #original line
rr38_sdf['Date'] = pd.to_datetime(rr38_sdf['Date'], format='%d-%m-%Y') # Changed the format string to match the actual format of the dates in your column

# Extract year from 'Date' column
rr38_sdf['Year'] = rr38_sdf['Date'].dt.year

# Calculate average value for each year
average_value_by_year = rr38_sdf.groupby('Year')['Value'].mean()

# Create the line chart
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
plt.plot(average_value_by_year.index, average_value_by_year.values)

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.title('Average Import and Export Value over Time')

# Rotate x-axis labels if needed
plt.xticks(rotation=45, ha='right')  # Adjust rotation and alignment as needed

# Show the chart
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# # Numerical Encoding of Categorical Data

# %%
oe = OrdinalEncoder()
oe_fit = oe.fit_transform( rr38_cat_mdi)
rr38_cat_code = pd.DataFrame(oe_fit, columns=['Import_Export_code', 'Category_code', 'Shipping_Method_code', 'Payment_Terms_code'])
rr38_cat_mdt_code_oe =   rr38_cat_code;  rr38_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
# rr38_cat_mdt_code_oe = pd.merge( rr38_cat_mdt_code,  rr38_cat_code_oe, left_index=True, right_index=True);  rr38_cat_mdt_code_oe
# Out:
#       Import_Export_code  Category_code  Shipping_Method_code  \
# 0                    1.0            4.0                   2.0
# 1                    1.0            3.0                   2.0
# 2                    1.0            1.0                   2.0
# 3                    1.0            1.0                   2.0
# 4                    1.0            4.0                   0.0
# ...                  ...            ...                   ...
# 4996                 0.0            4.0                   1.0
# 4997                 1.0            1.0                   1.0
# 4998                 0.0            4.0                   1.0
# 4999                 0.0            1.0                   0.0
# 5000                 1.0            0.0                   1.0
#
#       Payment_Terms_code
# 0                    0.0
# 1                    3.0
# 2                    2.0
# 3                    0.0
# 4                    2.0
# ...                  ...
# 4996                 0.0
# ...

# %% [markdown]
# # Scaling Of Non Categorical Data

# %%
scaled = MinMaxScaler()

rr38_nononcat_scaled = scaled.fit_transform(rr38_sdf_nononcat)

# Convert the scaled data back to a DataFrame
rr38_nononcat_scaled = pd.DataFrame(rr38_nononcat_scaled, columns=rr38_sdf_nononcat.columns)

# Display the scaled data
print(rr38_nononcat_scaled.head())
# Out:
#    Quantity     Value    Weight
# 0  0.690014  0.447882  0.060605
# 1  0.501601  0.157799  0.650963
# 2  0.261857  0.213361  0.432255
# 3  0.766760  0.690303  0.500912
# 4  0.570142  0.995272  0.146481

# %%
#combining of numerically encoded categorical and scaled non categorical line

rr38_sdf_clean = pd.concat([rr38_nononcat_scaled, rr38_cat_mdt_code_oe], axis=1)
rr38_sdf_clean.head()
# Out:
#    Quantity     Value    Weight  Import_Export_code  Category_code  \
# 0  0.690014  0.447882  0.060605                 1.0            4.0
# 1  0.501601  0.157799  0.650963                 1.0            3.0
# 2  0.261857  0.213361  0.432255                 1.0            1.0
# 3  0.766760  0.690303  0.500912                 1.0            1.0
# 4  0.570142  0.995272  0.146481                 1.0            4.0
#
#    Shipping_Method_code  Payment_Terms_code
# 0                   2.0                 0.0
# 1                   2.0                 3.0
# 2                   2.0                 2.0
# 3                   2.0                 0.0
# 4                   0.0                 2.0

# %% [markdown]
# # Data Bifurcation [Training & Testing Datasets]

# %%
# Dataset Used : sdf_ppd

train_sdf, test_sdf = train_test_split(rr38_sdf_clean, test_size=0.25, random_state=55038)
#train_sdf # Training Dataset
#test_sdf # Testing Dataset

# %% [markdown]
# # Clustering

# %% [markdown]
# ## K-means

# %%
# Analyse cluster characteristics using ANOVA for nononcat data and frequency for cat data
# Assuming rr38_importexport_subset is your DataFrame with relevant columns
rr38_importexport_subset = rr38_sdf

# 1. Select numerical features for clustering
rr38_cluster_data = rr38_importexport_subset[['Quantity', 'Value', 'Weight']]

# 2. Perform K-Means clustering (example with 3 clusters)
rr38_km_cluster = kmclus(n_clusters=3, init='random', random_state=55028)
rr38_importexport_subset['Cluster'] = rr38_km_cluster.fit_predict(rr38_cluster_data)

# 3. Display the results
print(rr38_importexport_subset[['Country', 'Product', 'Cluster']].head())  # Example display
# Out:
#            Country       Product  Cluster
# 4972    Kazakhstan        single        1
# 10055      Hungary  particularly        1
# 2920   Saint Lucia        become        0
# 11695     Botswana         store        2
# 9363      Suriname          cell        2

# %%
# 2.1.3. K-Means Clustering Model Evaluation [K=2 | K=3]
# ------------------------------------------------------
# Assuming rr38_importexport_subset and rr38_cluster_data are defined as in previous cells

# Perform K-Means clustering with 2 clusters
rr38_km_2cluster_model = kmclus(n_clusters=2, init='random', random_state=55038).fit(rr38_cluster_data)  # Define the model and fit it

rr38_sscore_km_2cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_2cluster_model.labels_);  # Use the fitted model's labels
rr38_sscore_km_2cluster
# Out:
# 0.308153668802852

# %%
rr38_dbscore_km_2cluster = dbscore(rr38_importexport_subset[['Quantity','Value','Weight']], rr38_km_2cluster_model.labels_)
rr38_dbscore_km_2cluster
# Out:
# 1.326462074268851

# %%
# Perform K-Means clustering with 3 clusters and evaluate
rr38_km_3cluster_model = kmclus(n_clusters=3, init='random', random_state=55038).fit(rr38_cluster_data)  # Define and fit the model with 3 clusters

# Calculate Silhouette Score for 3 clusters
#rr38_sscore_km_3cluster = sscore(rr38_ds_subset, rr38_km_3cluster_model); rr38_sscore_km_3cluster # Original line causing error
rr38_sscore_km_3cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_3cluster_model.labels_)  # Use rr38_importexport_subset and labels from 3-cluster model
print("Silhouette Score (3 Clusters):", rr38_sscore_km_3cluster)

# Calculate Davies-Bouldin Score for 3 clusters
#rr38_dbscore_km_3cluster = dbscore(rr38_ds_subset, rr38_km_3cluster_model); rr38_dbscore_km_3cluster # Original line causing error
rr38_dbscore_km_3cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_3cluster_model.labels_)  # Use rr38_importexport_subset and labels from 3-cluster model
print("Davies-Bouldin Score (3 Clusters):", rr38_dbscore_km_3cluster)
# Out:
# Silhouette Score (3 Clusters): 0.3193441459983968
# Davies-Bouldin Score (3 Clusters): 1.0133958204842861

# %%
# Perform K-Means clustering with 4 clusters
rr38_km_4cluster_model = kmclus(n_clusters=4, init='random', random_state=55038).fit(rr38_cluster_data)  # Define and fit the model with 4 clusters

# Calculate Silhouette Score for 4 clusters
rr38_sscore_km_4cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_4cluster_model.labels_)  # Use rr38_importexport_subset and labels from 4-cluster model
print("Silhouette Score (4 Clusters):", rr38_sscore_km_4cluster)

# Calculate Davies-Bouldin Score for 4 clusters
rr38_dbscore_km_4cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_4cluster_model.labels_)  # Use rr38_importexport_subset and labels from 4-cluster model
print("Davies-Bouldin Score (4 Clusters):", rr38_dbscore_km_4cluster)
# Out:
# Silhouette Score (4 Clusters): 0.3220837800465935
# Davies-Bouldin Score (4 Clusters): 0.9846699494973692

# %%
# Perform K-Means clustering with 5 clusters
rr38_km_5cluster_model = kmclus(n_clusters=5, init='random', random_state=55038).fit(rr38_cluster_data)  # Define and fit the model with 5 clusters

# Calculate Silhouette Score for 5 clusters
rr38_sscore_km_5cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_5cluster_model.labels_)  # Use rr38_importexport_subset and labels from 5-cluster model
print("Silhouette Score (5 Clusters):", rr38_sscore_km_5cluster)

# Calculate Davies-Bouldin Score for 5 clusters
rr38_dbscore_km_5cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_km_5cluster_model.labels_)  # Use rr38_importexport_subset and labels from 5-cluster model
print("Davies-Bouldin Score (5 Clusters):", rr38_dbscore_km_5cluster)
# Out:
# Silhouette Score (5 Clusters): 0.29112626697211264
# Davies-Bouldin Score (5 Clusters): 1.1452934277352325

# %% [markdown]
# - Silhouette Score : K=3 Cluster > K=2 Cluster => K=3 is more appropriate
# - Davies-Bouldin Score : K=3 Cluster < K=2 Cluster => K=3 is more appropriate
# - Appropriate Number of Clusters : 4 (Based on Silhouette Score & Davies-Bouldin Score)

# %%
# Create a KMeans Cluster Member Dataframe

# Cluster Model Used : km_3cluster_model

# Assuming 'rr38_importexport_subset' contains the data you want to cluster
rr38_ds_subset_kmcluster = rr38_importexport_subset.copy()  # Use rr38_importexport_subset instead of rr38_ds_subset
rr38_ds_subset_kmcluster.reset_index(level=0, inplace=True, names='index')
rr38_ds_subset_kmcluster['cluster_number'] = rr38_km_4cluster_model.labels_  # Assign cluster labels instead of the model object
rr38_ds_subset_kmcluster.sort_values('cluster_number', inplace=True)

# Display the DataFrame
rr38_ds_subset_kmcluster
# Out:
#       index                        Transaction_ID         Country   Product  \
# 2500  13679  b0f8e9b4-2d13-4494-bba6-aca730a9ed86      Micronesia  positive
# 3212   7154  8d9fc5bb-b04e-4114-92b2-52e20bef77b9     Timor-Leste  pressure
# 3213   2536  496f71e7-9643-4234-9569-1742aac3ab0f      Bangladesh    matter
# 3215   6906  69aa74cf-1bf0-4f91-9f25-8b40fabf2884         Liberia       cup
# 1163   1699  aac41158-0716-41dd-a7dd-f42ddd761afc          Angola      than
# ...     ...                                   ...             ...       ...
# 2731   7326  4b2eaf3a-5b74-4a44-8a14-b2ffb29156eb    Saudi Arabia       Mrs
# 681     628  00f24603-8295-4fe0-92c5-53b5d2f74429         Albania      pass
# 2732   9957  5c04fad2-301a-433c-8cf7-82ab1621338f  Norfolk Island      seek
# 3926  13657  011ac0a9-71aa-4a24-a8f2-c013c74bd12a          Jersey      land
# 1980   2016  a84cd94a-656f-475e-9969-1df6be961834         Iceland      away
#
# ...

# %%
# 2.3. Plot the K-Means Clustered Data


# Cluster Model Used : km_4cluster_model

rr38_cluster_labels = list(rr38_ds_subset_kmcluster['cluster_number'].unique())

# Using 'Quantity' and 'Value' for the scatter plot
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
rr38_scatter_plot = plt.scatter(x='Quantity', y='Value', data=rr38_ds_subset_kmcluster, c='cluster_number', cmap='brg')
plt.legend(handles=rr38_scatter_plot.legend_elements()[0], labels=rr38_cluster_labels)
plt.xlabel('Quantity')
plt.ylabel('Value')
plt.title('Import/Export: Value vs Quantity Scatter Plot : K-Means Clusters')
plt.grid()
plt.show()

# %% [markdown]
# ## Anglomerative Hierarchy Clustering

# %%
# 2 Cluster
from sklearn.cluster import AgglomerativeClustering


# Perform Agglomerative Clustering with 2 clusters
rr38_ag_2cluster_model = AgglomerativeClustering(n_clusters=2).fit(rr38_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 2 clusters
rr38_sscore_ag_2cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_2cluster_model.labels_)
print("Silhouette Score (2 Clusters - Agglomerative):", rr38_sscore_ag_2cluster)

# Calculate Davies-Bouldin Score for 2 clusters
rr38_dbscore_ag_2cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_2cluster_model.labels_)
print("Davies-Bouldin Score (2 Clusters - Agglomerative):", rr38_dbscore_ag_2cluster)
# Out:
# Silhouette Score (2 Clusters - Agglomerative): 0.27757873490855756
# Davies-Bouldin Score (2 Clusters - Agglomerative): 1.4332442025213656

# %%
# 3 Cluster

# Perform Agglomerative Clustering with 3 clusters
rr38_ag_3cluster_model = AgglomerativeClustering(n_clusters=3).fit(rr38_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 3 clusters
rr38_sscore_ag_3cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_3cluster_model.labels_)
print("Silhouette Score (3 Clusters - Agglomerative):", rr38_sscore_ag_3cluster)

# Calculate Davies-Bouldin Score for 3 clusters
rr38_dbscore_ag_3cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_3cluster_model.labels_)
print("Davies-Bouldin Score (3 Clusters - Agglomerative):", rr38_dbscore_ag_3cluster)
# Out:
# Silhouette Score (3 Clusters - Agglomerative): 0.23885823331027392
# Davies-Bouldin Score (3 Clusters - Agglomerative): 1.1277446845634687

# %%
# 4 Cluster

# Perform Agglomerative Clustering with 4 clusters
rr38_ag_4cluster_model = AgglomerativeClustering(n_clusters=4).fit(rr38_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 4 clusters
rr38_sscore_ag_4cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_4cluster_model.labels_)
print("Silhouette Score (4 Clusters - Agglomerative):", rr38_sscore_ag_4cluster)

# Calculate Davies-Bouldin Score for 4 clusters
rr38_dbscore_ag_4cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_4cluster_model.labels_)
print("Davies-Bouldin Score (4 Clusters - Agglomerative):", rr38_dbscore_ag_4cluster)
# Out:
# Silhouette Score (4 Clusters - Agglomerative): 0.24715292017173796
# Davies-Bouldin Score (4 Clusters - Agglomerative): 1.1124369513388426

# %%
# 5 Cluster

# Perform Agglomerative Clustering with 5 clusters
rr38_ag_5cluster_model = AgglomerativeClustering(n_clusters=5).fit(rr38_importexport_subset[['Quantity', 'Value', 'Weight']])  # Define and fit the model

# Calculate Silhouette Score for 5 clusters
rr38_sscore_ag_5cluster = sscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_5cluster_model.labels_)
print("Silhouette Score (5 Clusters - Agglomerative):", rr38_sscore_ag_5cluster)

# Calculate Davies-Bouldin Score for 5 clusters
rr38_dbscore_ag_5cluster = dbscore(rr38_importexport_subset[['Quantity', 'Value', 'Weight']], rr38_ag_5cluster_model.labels_)
print("Davies-Bouldin Score (5 Clusters - Agglomerative):", rr38_dbscore_ag_5cluster)
# Out:
# Silhouette Score (5 Clusters - Agglomerative): 0.2189529817147175
# Davies-Bouldin Score (5 Clusters - Agglomerative): 1.2671634326855366

# %%
# Making a data frame of 3 cluster

# Get cluster labels from the model
cluster_labels = rr38_ag_3cluster_model.labels_

# Create a DataFrame with cluster labels
cluster_df = pd.DataFrame({'Cluster': cluster_labels}, index=rr38_importexport_subset.index)

# Add cluster labels to the original DataFrame
rr38_importexport_subset['Cluster'] = cluster_labels

# Display the DataFrame with cluster labels
rr38_importexport_subset.head()
# Out:
#                              Transaction_ID      Country       Product  \
# 4972   4bad5842-b0c7-410e-bc4f-d2fa3dab6e30   Kazakhstan        single
# 10055  2ed16181-3218-4baa-b701-097b568c1fa9      Hungary  particularly
# 2920   ce6185b7-e6fb-4f80-bc3f-9774732eba92  Saint Lucia        become
# 11695  6e81983d-f9b4-4417-9b0a-ef5f1e405ce5     Botswana         store
# 9363   a3a3084d-93f4-427b-8d86-cc8e36321cb3     Suriname          cell
#
#       Import_Export  Quantity    Value       Date     Category           Port  \
# 4972         Import      6902  4536.94 2022-02-04         Toys     North Ryan
# 10055        Import      5019  1667.66 2022-09-26    Machinery     Brownville
# 2920         Import      2623  2217.23 2019-12-25  Electronics  Courtneyshire
# 11695        Import      7669  6934.78 2023-12-30  Electronics   East Anthony
# 9363         Import      5704  9951.30 2023-08-27         Toys  Lake Lorifort
#
# ...

# %%
#Vizualizing 3 Cluster

# Add cluster labels to the DataFrame
rr38_sdf['Cluster'] = cluster_labels

# Choose two features for the scatter plot (e.g., 'Quantity' and 'Value')
x_column = 'Quantity'
y_column = 'Value'

# Create the scatter plot
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(rr38_sdf[x_column], rr38_sdf[y_column], c=rr38_sdf['Cluster'], cmap='viridis')

# Add labels and title
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.title('Scatter Plot of Clusters')

# Add a colorbar to show cluster mapping
plt.colorbar(label='Cluster')

# Show the plot
plt.show()
